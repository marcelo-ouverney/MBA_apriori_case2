# %% [markdown]
# #### Import dos pacotes e set de configurações

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

pd.set_option('display.max_rows', 500)

# %% [markdown]
# #### Import dos dados

# %%
acid_df = pd.read_csv('acidentes-apriori.csv', sep=';')

# %%
acid_df.head()
# Out:
#     dia_semana  uf                       causa_acidente  \
# 0  terca-feira  SP            Falta de Atencao Conducao
# 1  terca-feira  PR            Falta de Atencao Conducao
# 2  terca-feira  SC                     Animais na Pista
# 3  terca-feira  CE  Ingestao de Substancias Psicoativas
# 4  terca-feira  MG            Falta de Atencao Conducao
#
#                  tipo_acidente classificacao_acidente     fase_dia  \
# 0  Colisao com objeto estatico    Com Vitimas Feridas  Plena Noite
# 1             Colisao traseira    Com Vitimas Feridas  Plena Noite
# 2  Colisao com objeto estatico    Com Vitimas Feridas  Plena Noite
# 3  Colisao com objeto estatico    Com Vitimas Feridas  Plena Noite
# 4          Colisao transversal    Com Vitimas Feridas  Plena Noite
#
#   condicao_metereologica         tracado_via
# 0              Ceu Claro               Curva
# 1                Nublado                Reta
# 2              Ceu Claro                Reta
# 3                Nublado             Viaduto
# 4                Nublado  Intersecao de vias

# %%
# formato dos dados
acid_df.shape
# Out:
# (20882, 8)

# %% [markdown]
# Vemos que são cerca de 20k registros, com 8 colunas

# %%
# verificando se há alguma resposta nula
acid_df.isna().sum()
# Out:
# dia_semana                0
# uf                        0
# causa_acidente            0
# tipo_acidente             0
# classificacao_acidente    0
# fase_dia                  0
# condicao_metereologica    0
# tracado_via               0
# dtype: int64

# %%
# vamos entender as proporções de cada resposta no df
for col in acid_df.columns:
    print('\n\n ---------{}---------'.format(col))
    print(acid_df[col].value_counts(normalize=True))
# Out:
#  ---------dia_semana---------
# sabado           0.167177
# domingo          0.162053
# sexta-feira      0.149555
# segunda-feira    0.134805
# terca-feira      0.132698
# quinta-feira     0.129442
# quarta-feira     0.124270
# Name: dia_semana, dtype: float64
#
#
#  ---------uf---------
# MG    0.130112
# SC    0.126233
# PR    0.115458
# RJ    0.069342
# RS    0.066517
# SP    0.065942
# BA    0.050139
# GO    0.049852
# ES    0.041711
# PE    0.041088
# MT    0.031558
# CE    0.025764
# PB    0.024710
# RO    0.021214
# MS    0.020640
# PI    0.019874
# RN    0.019778
# MA    0.016378
# DF    0.014366
# PA    0.011876
# SE    0.010200
# AL    0.010104
# TO    0.007710
# RR    0.003352
# AC    0.002873
# AP    0.001963
# AM    0.001245
# Name: uf, dtype: float64
#
#
#  ---------causa_acidente---------
# Falta de Atencao Conducao                                                           0.363136
# Desobediencia nas normas de transito pelo condutor                                  0.114501
# Velocidade Incompativel                                                             0.095010
# Ingestao de Alcool                                                                  0.076477
# Nao guardar distancia de seguranca                                                  0.065559
# Defeito Mecanico no Veiculo                                                         0.057131
# Condutor Dormindo                                                                   0.039172
# Pista Escorregadia                                                                  0.038454
# Falta de Atencao do Pedestre                                                        0.028206
# Animais na Pista                                                                    0.022747
# Ultrapassagem Indevida                                                              0.018006
# Defeito na Via                                                                      0.016330
# Avarias e/ou desgaste excessivo no pneu                                             0.014175
# Mal Subito                                                                          0.010583
# Restricao de Visibilidade                                                          0.007135
# Agressao Externa                                                                    0.006561
# Ingestao de Alcool e/ou substancias psicoativas pelo pedestre                       0.005938
# Desobedincia nas normas de transito pelo pedestre                                  0.005124
# Carga excessiva e/ou mal acondicionada                                              0.004645
# Fenomenos da Natureza                                                               0.004118
# Sinalizacao da via insuficiente ou inadequada                                      0.003687
# Deficincia ou nao Acionamento do Sistema de Iluminacao/Sinalizacao do Veiculo    0.001724
# Ingestao de Substancias Psicoativas                                                 0.001580
# Name: causa_acidente, dtype: float64
#
#
#  ---------tipo_acidente---------
# Colisao traseira                   0.190595
# Saida de leito carrocavel          0.158605
# Colisao transversal                0.127622
# Colisao lateral                    0.122402
# Tombamento                         0.079590
# Colisao frontal                    0.066517
# Colisao com objeto estatico        0.064122
# Queda de ocupante de veiculo       0.048559
# Atropelamento de Pedestre          0.048367
# Capotamento                        0.036778
# Atropelamento de Animal            0.018006
# Incendio                          0.015612
# Engavetamento                      0.013600
# Colisao com objeto em movimento    0.004406
# Derramamento de carga              0.003017
# Danos eventuais                    0.002203
# Name: tipo_acidente, dtype: float64
#
#
#  ---------classificacao_acidente---------
# Com Vitimas Feridas    0.760895
# Sem Vitimas            0.174696
# Com Vitimas Fatais     0.064410
# Name: classificacao_acidente, dtype: float64
#
#
#  ---------fase_dia---------
# Pleno dia      0.573221
# Plena Noite    0.327172
# Anoitecer      0.053683
# Amanhecer      0.045925
# Name: fase_dia, dtype: float64
#
#
#  ---------condicao_metereologica---------
# Ceu Claro           0.539556
# Nublado             0.192367
# Chuva               0.132698
# Sol                 0.079734
# Garoa/Chuvisco      0.036299
# Ignorado            0.012403
# Nevoeiro/Neblina    0.005268
# Vento               0.001676
# Name: condicao_metereologica, dtype: float64
#
#
#  ---------tracado_via---------
# Reta                     0.610430
# Curva                    0.165741
# Nao Informado            0.102337
# Intersecao de vias       0.049181
# Desvio Temporario        0.027105
# Rotatoria                0.020017
# Retorno Regulamentado    0.011397
# Viaduto                  0.007758
# Ponte                    0.004741
# Tunel                    0.001293
# Name: tracado_via, dtype: float64

# %% [markdown]
# #### Transformando os dados em lista de listas

# %%
# aplicando a transformação para a lista de listas

acid_lst = []
for i in range(0, acid_df.shape[0]):
    acid_cols = []
    for j in range(0, acid_df.shape[1]):        
        acid_cols.append(str(acid_df.values[i,j]))
    acid_lst.append(acid_cols)

# %%
# visualizando as 5 primeiras entradas
acid_lst[:5]
# Out:
# [['terca-feira',
#   'SP',
#   'Falta de Atencao Conducao',
#   'Colisao com objeto estatico',
#   'Com Vitimas Feridas',
#   'Plena Noite',
#   'Ceu Claro',
#   'Curva'],
#  ['terca-feira',
#   'PR',
#   'Falta de Atencao Conducao',
#   'Colisao traseira',
#   'Com Vitimas Feridas',
#   'Plena Noite',
#   'Nublado',
#   'Reta'],
#  ['terca-feira',
#   'SC',
#   'Animais na Pista',
#   'Colisao com objeto estatico',
#   'Com Vitimas Feridas',
#   'Plena Noite',
#   'Ceu Claro',
#   'Reta'],
#  ['terca-feira',
#   'CE',
#   'Ingestao de Substancias Psicoativas',
#   'Colisao com objeto estatico',
#   'Com Vitimas Feridas',
#   'Plena Noite',
#   'Nublado',
#   'Viaduto'],
#  ['terca-feira',
#   'MG',
#   'Falta de Atencao Conducao',
#   'Colisao transversal',
#   'Com Vitimas Feridas',
#   'Plena Noite',
#   'Nublado',
#   'Intersecao de vias']]

# %% [markdown]
# #### Aplicação do Transaction Encoder

# %%
te = TransactionEncoder()

# Coloca em memória as trasações e interpreta a quantidade de colunas 
# que serão geradas durante o processamento
te.fit(acid_lst)
# Out:
# TransactionEncoder()

# %%
# O objeto TransactionEncoder faz a conversão das transações em uma matriz binária,
# onde cada linha da matriz representa uma transação
matriz_transacoes = te.transform(acid_lst)

# Cria um dataframe auxiliar com a matriz binária (passo te.transform(transacoes)) 
# de transações e as colunas obtidas (passo te.fit(transacoes))
dfAuxiliar = pd.DataFrame(matriz_transacoes, columns=te.columns_)

dfAuxiliar.head()
# Out:
#       AC     AL     AM     AP  Agressao Externa  Amanhecer  Animais na Pista  \
# 0  False  False  False  False             False      False             False
# 1  False  False  False  False             False      False             False
# 2  False  False  False  False             False      False              True
# 3  False  False  False  False             False      False             False
# 4  False  False  False  False             False      False             False
#
#    Anoitecer  Atropelamento de Animal  Atropelamento de Pedestre  ...  \
# 0      False                    False                      False  ...
# 1      False                    False                      False  ...
# 2      False                    False                      False  ...
# 3      False                    False                      False  ...
# 4      False                    False                      False  ...
#
#    Velocidade Incompativel  Vento  Viaduto  domingo  quarta-feira  \
# 0                    False  False    False    False         False
# 1                    False  False    False    False         False
# 2                    False  False    False    False         False
# 3                    False  False     True    False         False
# 4                    False  False    False    False         False
#
#    quinta-feira  sabado  segunda-feira  sexta-feira  terca-feira
# 0         False   False          False        False         True
# 1         False   False          False        False         True
# 2         False   False          False        False         True
# 3         False   False          False        False         True
# 4         False   False          False        False         True
#
# [5 rows x 98 columns]

# %% [markdown]
# Neste ponto vale destacar que um suporte muito baixo dá uma quantidade muito alta de combinações, e os *insights* obtidos não serão de grande valor, pois representam poucos casos do total. Assim, optaremos por um **suporte mínimo de 5%**, que mantém os principais tipos de colisão em análise.

# %%
# Obtêm os itemsets mais frequentes com um suporte mínimo igual a 5%
# O paramêtro use_colnames significa que vamos usar os nomes das colunas do DataFrame 
# dfAuxiliar para construir as regras de Associação

itemsets_freq = apriori(dfAuxiliar, min_support=0.05, use_colnames=True)
print(itemsets_freq.head())
# Out:
#     support                       itemsets
# 0  0.053683                    (Anoitecer)
# 1  0.050139                           (BA)
# 2  0.539556                    (Ceu Claro)
# 3  0.132698                        (Chuva)
# 4  0.064122  (Colisao com objeto estatico)

# %% [markdown]
# #### Obtenção das regras de Associação

# %%
# Obtém as regras de associação a partir dos itemsets mais frequentes.
# Vamos definir uma confiança mínima de 50% para análise, de forma a 
# formar análises fortes
regras = association_rules(itemsets_freq, metric="confidence", min_threshold=0.5)

# Ordena as Regras por confiança
regrasOrdenadas = regras.sort_values('confidence' , ascending=False)

# %%
regrasOrdenadas.shape
# Out:
# (315, 9)

# %% [markdown]
# Temos cerca de 315 regras possíveis a analisar

# %%
regrasOrdenadas.head()
# Out:
#                                           antecedents            consequents  \
# 79                                              (Sol)            (Pleno dia)
# 221                        (Com Vitimas Feridas, Sol)            (Pleno dia)
# 170                  (Pleno dia, Colisao transversal)  (Com Vitimas Feridas)
# 168  (Falta de Atencao Conducao, Colisao transversal)  (Com Vitimas Feridas)
# 215                                   (Pleno dia, SC)  (Com Vitimas Feridas)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 79             0.079734            0.573221  0.078345    0.982583  1.714143
# 221            0.065319            0.573221  0.064170    0.982405  1.713832
# 170            0.084092            0.760895  0.072982    0.867882  1.140607
# 168            0.065703            0.760895  0.056891    0.865889  1.137988
# 215            0.074705            0.760895  0.064074    0.857692  1.127216
#
#      leverage  conviction
# 79   0.032640   24.503004
# 221  0.026728   24.255276
# 170  0.008997    1.809781
# 168  0.006898    1.782895
# 215  0.007231    1.680200

# %% [markdown]
# ## Análise das Regras de Associação

# %% [markdown]
# ##### Vamos analisar os casos com **vítimas fatais**:

# %%
termo = 'Com Vitimas Fatais'
# criando lista com índices de interesse
filtro = []
for index, row in regrasOrdenadas.iterrows():
    for ent in row['antecedents']:
        if ent == termo:
            filtro.append(index)
            break

regrasOrdenadas.loc[regrasOrdenadas.index.isin(filtro), : ][['antecedents','consequents','confidence', 'support']]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, confidence, support]
# Index: []

# %%
termo = 'Com Vitimas Fatais'
# criando lista com índices de interesse
filtro = []
for index, row in regrasOrdenadas.iterrows():
    for ent in row['consequents']:
        if ent == termo:
            filtro.append(index)
            break

regrasOrdenadas.loc[regrasOrdenadas.index.isin(filtro), : ][['antecedents','consequents','confidence', 'support']]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, confidence, support]
# Index: []

# %% [markdown]
#  - Vemos que não há regras fortes associadas aos casos de vítimas fatais

# %% [markdown]
# ##### Agora analisando os **casos sem vítimas**:

# %%
termo = 'Sem Vitimas'
# criando lista com índices de interesse
filtro = []
for index, row in regrasOrdenadas.iterrows():
    for ent in row['antecedents']:
        if ent == termo:
            filtro.append(index)
            break

regrasOrdenadas.loc[regrasOrdenadas.index.isin(filtro), : ][['antecedents','consequents','confidence', 'support']]
# Out:
#                   antecedents  consequents  confidence   support
# 148  (Ceu Claro, Sem Vitimas)       (Reta)    0.645812  0.059812
# 89              (Sem Vitimas)       (Reta)    0.602522  0.105258
# 260  (Pleno dia, Sem Vitimas)       (Reta)    0.587597  0.054449
# 149       (Sem Vitimas, Reta)  (Ceu Claro)    0.568244  0.059812
# 78              (Sem Vitimas)  (Pleno dia)    0.530428  0.092664
# 14              (Sem Vitimas)  (Ceu Claro)    0.530154  0.092616
# 261       (Sem Vitimas, Reta)  (Pleno dia)    0.517288  0.054449

# %% [markdown]
# - Vemos que, em 60% dos acidentes sem vítimas, o acidente ocorreu em retas. Também, 53% ocorreram em pleno dia e 53% com céu claro

# %% [markdown]
# ##### Analisando os casos com **vítimas feridas**:

# %%
termo = 'Com Vitimas Feridas'
# criando lista com índices de interesse
filtro = []
for index, row in regrasOrdenadas.iterrows():
    for ent in row['consequents']:
        if ent == termo:
            filtro.append(index)
            break

regrasOrdenadas.loc[regrasOrdenadas.index.isin(filtro), : ][['antecedents','consequents','confidence', 'support']]
# Out:
#                                            antecedents  \
# 170                   (Pleno dia, Colisao transversal)
# 168   (Falta de Atencao Conducao, Colisao transversal)
# 215                                    (Pleno dia, SC)
# 28                               (Colisao transversal)
# 99                    (Ceu Claro, Colisao transversal)
# 173                        (Colisao transversal, Reta)
# 187  (Pleno dia, Desobediencia nas normas de transi...
# 158       (Falta de Atencao Conducao, Colisao lateral)
# 309  (Pleno dia, Falta de Atencao Conducao, Reta, C...
# 304       (Pleno dia, Reta, Falta de Atencao Conducao)
# 276  (Pleno dia, Falta de Atencao Conducao, Ceu Claro)
# 194             (Pleno dia, Falta de Atencao Conducao)
# 40                (Nao guardar distancia de seguranca)
# 200                                    (Pleno dia, MG)
# 280       (Falta de Atencao Conducao, Reta, Ceu Claro)
# 160                       (Pleno dia, Colisao lateral)
# 52                                               (Sol)
# 220                                   (Pleno dia, Sol)
# 224                          (Pleno dia, quarta-feira)
# 109  (Ceu Claro, Desobediencia nas normas de transi...
# 197                  (Falta de Atencao Conducao, Reta)
# 192               (Falta de Atencao Conducao, Nublado)
# 191  (Desobediencia nas normas de transito pelo con...
# 112             (Falta de Atencao Conducao, Ceu Claro)
# 238                                         (SC, Reta)
# 37                         (Falta de Atencao Conducao)
# 36   (Desobediencia nas normas de transito pelo con...
# 294  (Falta de Atencao Conducao, Colisao traseira, ...
# 236                           (Pleno dia, terca-feira)
# 49                                                (SC)
# 163                            (Colisao lateral, Reta)
# 231                         (Pleno dia, segunda-feira)
# 205                               (Pleno dia, Nublado)
# 97                        (Ceu Claro, Colisao lateral)
# 222                                              (Sol)
# 297                (Pleno dia, Colisao traseira, Reta)
# 175      (Falta de Atencao Conducao, Colisao traseira)
# 53                                        (Tombamento)
# 202                                         (MG, Reta)
# 176                      (Pleno dia, Colisao traseira)
# 234                           (Pleno dia, sexta-feira)
# 269           (Pleno dia, Colisao traseira, Ceu Claro)
# 24                                   (Colisao lateral)
# 208                                    (Pleno dia, PR)
# 212                                  (Pleno dia, Reta)
# 38                                                (MG)
# 301     (Falta de Atencao Conducao, Reta, Plena Noite)
# 44                                         (Pleno dia)
# 193           (Falta de Atencao Conducao, Plena Noite)
# 178                           (Colisao traseira, Reta)
# 287                       (Pleno dia, Reta, Ceu Claro)
# 118                             (Pleno dia, Ceu Claro)
# 32                                  (Colisao traseira)
# 61                                       (terca-feira)
# 114                                    (MG, Ceu Claro)
# 244                               (quarta-feira, Reta)
# 136                           (Ceu Claro, terca-feira)
# 50                                                (SP)
# 252                                (sexta-feira, Reta)
# 227                          (Pleno dia, quinta-feira)
# 101                      (Ceu Claro, Colisao traseira)
# 56                                      (quarta-feira)
# 271                (Ceu Claro, Colisao traseira, Reta)
# 46                                                (RJ)
# 59                                     (segunda-feira)
# 60                                       (sexta-feira)
# 157                                 (Chuva, Pleno dia)
# 254                                (Reta, terca-feira)
# 126                          (Ceu Claro, quarta-feira)
# 185                                 (Pleno dia, Curva)
# 233  (Pleno dia, Com Vitimas Feridas)    0.503730  0.067905
# 290       (Com Vitimas Feridas, Reta)    0.501870  0.154200

# %% [markdown]
# - Vemos que o tipo de acidente mais grave é o ocorrido em pleno dia, por colisão transversal, que implica em Vítimas Feridas em 87% dos casos!
# - Também, os acidentes em Pleno dia em SC implicam em vítimas feridas em 87% dos casos.
# - Analisando somente os estados, temos um indicativo de que realmente SC tende a ter acidentes com vítimas feridas maior que outros estados. SC apresenta acidentes com vítimas feridas em 80,9% dos casos. Já o PR apresenta acidentes com vítimas feridas em 75% dos casos.
# - Terça-feira tem acidentes com vítimas feridas em 78% dos casos, enquanto aos sábados e domingos este percentual é menor, com cerca de 73% dos casos.

# %% [markdown]
# ##### Vamos agora analisar os **casos de ingestão de álcool**:

# %%
termo = 'Ingestao de Alcool'
# criando lista com índices de interesse
filtro = []
for index, row in regrasOrdenadas.iterrows():
    for ent in row['antecedents']:
        if ent == termo:
            filtro.append(index)
            break

regrasOrdenadas.loc[regrasOrdenadas.index.isin(filtro), : ][['antecedents','consequents','confidence', 'support']]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, confidence, support]
# Index: []

# %% [markdown]
# - Não há nenhuma regra forte associada ao consumo de álcool

# %% [markdown]
# ##### Analisando agora os casos de **Velocidade Incompatível** com a via:

# %%
termo = 'Velocidade Incompativel'
# criando lista com índices de interesse
filtro = []
for index, row in regrasOrdenadas.iterrows():
    for ent in row['antecedents']:
        if ent == termo:
            filtro.append(index)
            break

regrasOrdenadas.loc[regrasOrdenadas.index.isin(filtro), : ][['antecedents','consequents','confidence', 'support']]
# Out:
#                   antecedents            consequents  confidence   support
# 54  (Velocidade Incompativel)  (Com Vitimas Feridas)    0.721270  0.068528
# 80  (Velocidade Incompativel)            (Pleno dia)    0.608871  0.057849

# %% [markdown]
# - 72% dos acidentes por Velocidade Incompatível tiveram vítimas feridas
# - 61% dos acidentes por Velocidade Incompatível ocorreram em pleno dia

# %% [markdown]
# ##### Analisando agora os casos de **Falta de Atenção na Condução**:

# %%
termo = 'Falta de Atencao Conducao'
# criando lista com índices de interesse
filtro = []
for index, row in regrasOrdenadas.iterrows():
    for ent in row['antecedents']:
        if ent == termo:
            filtro.append(index)
            break

regrasOrdenadas.loc[regrasOrdenadas.index.isin(filtro), : ][['antecedents','consequents','confidence', 'support']]
# Out:
#                                            antecedents  \
# 168   (Falta de Atencao Conducao, Colisao transversal)
# 158       (Falta de Atencao Conducao, Colisao lateral)
# 309  (Pleno dia, Falta de Atencao Conducao, Reta, C...
# 304       (Pleno dia, Reta, Falta de Atencao Conducao)
# 276  (Pleno dia, Falta de Atencao Conducao, Ceu Claro)
# 194             (Pleno dia, Falta de Atencao Conducao)
# 280       (Falta de Atencao Conducao, Reta, Ceu Claro)
# 197                  (Falta de Atencao Conducao, Reta)
# 192               (Falta de Atencao Conducao, Nublado)
# 112             (Falta de Atencao Conducao, Ceu Claro)
# 37                         (Falta de Atencao Conducao)
# 294  (Falta de Atencao Conducao, Colisao traseira, ...
# 175      (Falta de Atencao Conducao, Colisao traseira)
# 294             (Com Vitimas Feridas)    0.810409  0.052198
# 175             (Com Vitimas Feridas)    0.804661  0.069438
# 301             (Com Vitimas Feridas)    0.793772  0.054928
# 193             (Com Vitimas Feridas)    0.790783  0.082176
# 295                            (Reta)    0.751724  0.052198
# 182                            (Reta)    0.746393  0.064410
# 281                            (Reta)    0.682232  0.114740
# 142                            (Reta)    0.679684  0.140025
# 311                            (Reta)    0.670846  0.071736
# 302                            (Reta)    0.668415  0.054928
# 292                            (Reta)    0.668398  0.086294
# 256                            (Reta)    0.665899  0.069198
# 198                            (Reta)    0.653279  0.193181
# 66                             (Reta)    0.650798  0.236328
# 305                            (Reta)    0.644290  0.119960
# 257                            (Reta)    0.641899  0.144383
# 277                       (Pleno dia)    0.635820  0.106934
# 195                       (Pleno dia)    0.629636  0.186189
# 140                       (Pleno dia)    0.626685  0.129106
# 312                       (Pleno dia)    0.625209  0.071736
# 306                       (Pleno dia)    0.620972  0.119960
# 65                        (Pleno dia)    0.619412  0.224931
# 181                       (Pleno dia)    0.619312  0.053443
# 293                       (Pleno dia)    0.616279  0.086294
# 258                       (Pleno dia)    0.610942  0.144383
# 296       (Com Vitimas Feridas, Reta)    0.604883  0.052198
# 310                       (Ceu Claro)    0.598004  0.071736
# 291                       (Ceu Claro)    0.597678  0.086294
# 279                       (Ceu Claro)    0.593951  0.114740
# 103                       (Ceu Claro)    0.592675  0.051145
# 141                       (Ceu Claro)    0.592503  0.140025
# 275                       (Ceu Claro)    0.574331  0.106934
# 139                       (Ceu Claro)    0.573983  0.129106
# 111                       (Ceu Claro)    0.568745  0.168183
# 6                         (Ceu Claro)    0.567322  0.206015
# 282       (Com Vitimas Feridas, Reta)    0.556950  0.114740
# 313       (Com Vitimas Feridas, Reta)    0.555638  0.071736
# 138                       (Ceu Claro)    0.548848  0.057035
# 307       (Com Vitimas Feridas, Reta)    0.533319  0.119960
# 199       (Com Vitimas Feridas, Reta)    0.531979  0.193181
# 303       (Com Vitimas Feridas, Reta)    0.528571  0.054928
# 278  (Pleno dia, Com Vitimas Feridas)    0.519061  0.106934
# 196  (Pleno dia, Com Vitimas Feridas)    0.512726  0.186189
# 314  (Pleno dia, Com Vitimas Feridas)    0.512312  0.071736
# 308  (Pleno dia, Com Vitimas Feridas)    0.507599  0.119960

# %% [markdown]
# - Os casos de falta de atenção na condução implicam em acidentes com vítimas feridas em 81% dos casos!
# - Quando comparados aos casos de velocidade incompatível, nota-se que este caso é mais grave, pois o % calculado anteriormente é 72% dos casos, sugerindo que este tipo de acidente é mais perigoso
# - Quando analisados os casos de falta de atenção com colisão transversal, este caso é ainda mais grave, com 86,6% dos casos com acidentes com vítimas feridas. Análise similar pode-se fazer com as colisões laterais, com taxa de acidentes com vítimas feridas de 83% dos casos

# %% [markdown]
# ##### Analisando agora os casos de **Desobediência das Normas de Trânsito**:

# %%
termo = 'Desobediencia nas normas de transito pelo condutor'
# criando lista com índices de interesse
filtro = []
for index, row in regrasOrdenadas.iterrows():
    for ent in row['antecedents']:
        if ent == termo:
            filtro.append(index)
            break

regrasOrdenadas.loc[regrasOrdenadas.index.isin(filtro), : ][['antecedents','consequents','confidence', 'support']]
# Out:
#                                            antecedents  \
# 270  (Pleno dia, Desobediencia nas normas de transi...
# 143  (Ceu Claro, Desobediencia nas normas de transi...
# 274  (Desobediencia nas normas de transito pelo con...
# 43   (Desobediencia nas normas de transito pelo con...
# 271  (Desobediencia nas normas de transito pelo con...
# 72   (Desobediencia nas normas de transito pelo con...
# 144  (Desobediencia nas normas de transito pelo con...
# 6    (Desobediencia nas normas de transito pelo con...
# 273  (Desobediencia nas normas de transito pelo con...
# 73   (Desobediencia nas normas de transito pelo con...
# 272  (Desobediencia nas normas de transito pelo con...
# 145  (Desobediencia nas normas de transito pelo con...
# 275  (Desobediencia nas normas de transito pelo con...
#
#                           consequents  confidence   support
# 270             (Com Vitimas Feridas)    0.839286  0.058519
# 143             (Com Vitimas Feridas)    0.817601  0.055167
# 274             (Com Vitimas Feridas)    0.816460  0.053683
# 43              (Com Vitimas Feridas)    0.813049  0.093095
# 271                       (Pleno dia)    0.628601  0.058519
# 72                        (Pleno dia)    0.608950  0.069725
# 144                       (Ceu Claro)    0.592593  0.055167
# 6                         (Ceu Claro)    0.589293  0.067474
# 273                            (Reta)    0.576646  0.053683
# 73                             (Reta)    0.574237  0.065750
# 272  (Pleno dia, Com Vitimas Feridas)    0.511083  0.058519
# 145  (Ceu Claro, Com Vitimas Feridas)    0.481807  0.055167
# 275       (Reta, Com Vitimas Feridas)    0.468841  0.053683

# %% [markdown]
# - Os casos de Desobediência às Leis em Pleno Dia também são graves, uma vez que implicam em vítimas feridas em ~84% dos casos.

# %% [markdown]
# ### Conclusões

# %% [markdown]
# Alguns *insights* importantes podem ser obtidos a partir dos dados analisados, como:
# - Em 60% dos acidentes sem vítimas, o acidente ocorreu em retas. Também, 53% ocorreram em pleno dia e 53% com céu claro. Nenhuma destas regras, entretanto, pode ser obtida nos casos de acidentes com vítimas fatais

# %% [markdown]
# Sobre a gravidade dos acidentes:
# - O tipo de acidente mais grave é o ocorrido em pleno dia, por colisão transversal, que implica em Vítimas Feridas em 87% dos casos!
# - Os acidentes em Pleno dia em SC implicam em vítimas feridas em 87% dos casos!
# - Comparando somente os estados, temos um indicativo de que realmente SC tende a ter acidentes com vítimas feridas maior que outros estados. SC apresenta acidentes com vítimas feridas em 80,9% dos casos. Já o PR apresenta acidentes com vítimas feridas em 75% dos casos. Aqui vale ressaltar que não temos todos os estados inclusos na análise, por não atingirem o suporte ou a confiança mínima. O que se deseja aqui é mostrar que SC aparenta implicar em acidentes mais graves que outros estados.
# - Terça-feira tem acidentes com vítimas feridas em 78% dos casos, enquanto aos sábados e domingos este percentual é menor, com cerca de 73% dos casos.

# %% [markdown]
# Sobre a causa dos acidentes:

# %% [markdown]
# - Nao pode-se obter *insights* fortes sobre acidentes ocorridos por ingestão de álcool
# - Acidentes por Falta de Atenção do Condutor e por Desobediência das Normas de Trânsito são mais graves que acidentes por Velocidade Incompatíveis com a Via, pois implicam em maior percentual de acidentes com vítimas feridas.
